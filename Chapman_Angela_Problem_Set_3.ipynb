# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Web Scraping Data

# %%
url = 'https://en.wikipedia.org/wiki/MonsterVerse'
df = pd.read_html(url)

# Selecting the particular table (#4)vas specified in the Problem Set Instructions
df = df[3]
df
# Out:
#               Character                          Films  \
#               Character                       Godzilla
#                Monsters                       Monsters
# 0              Godzilla                    T.J. StormS
# 1                  MUTO           Matt CrossSLee RossS
# 2             King Kong                            NaN
# 3         King Ghidorah                            NaN
# 4                 Rodan                            NaN
# 5                Humans                         Humans
# 6       Ishiro Serizawa                   Ken Watanabe
# 7       Vivienne Graham                  Sally Hawkins
# 8        William Stentz               David Strathairn
# 9            Ford Brody  Aaron Taylor-JohnsonCJ AdamsY
# 10           Elle Brody                Elizabeth Olsen
# 11            Joe Brody                 Bryan Cranston
# 12         Sandra Brody               Juliette Binoche
# 13       Houston Brooks                            NaN
# ...

# %% [markdown]
# # Cleaning Up the DataFrame Steps 1-3 Function

# %%
def clean_table(df):
    # Turn MultiIndex columns, or tuples, into a list of tuples
    df_list = list(df.columns)
    # Empty movie list act as a way for all the movie column headers to be renamed to proper single column header
    movies = []
    # This index allows access to the 2nd level of the column headers, aka gives access to the movies
    ind = 1

    for col in df_list:
        # Access to the particular movie out of the column headers
        if col[ind] == 'Character':
            # Setting the charcter column as the index and dropping the original column 
            df.index = df[df.columns[0]]
            df.index.name = 'character'
            df = df.drop(columns = ['Character'])
        else:
            # Creating movies list so that the new columns can be created later
            movies.append(col[ind])
    
    # Setting the new column as single column headers for the movies instead of the MultiIndex
    df.columns = movies
    # df.drop("Humans") could not do, could not figure out how to drop the humans row and apply to fast & furious
                          

            
    return df

# %% [markdown]
# # Running Function

# %%
clean_table(df)
# Out:
#                                           Godzilla  \
# character
# Godzilla                               T.J. StormS
# MUTO                          Matt CrossSLee RossS
# King Kong                                      NaN
# King Ghidorah                                  NaN
# Rodan                                          NaN
# Humans                                      Humans
# Ishiro Serizawa                       Ken Watanabe
# Vivienne Graham                      Sally Hawkins
# William Stentz                    David Strathairn
# Ford Brody           Aaron Taylor-JohnsonCJ AdamsY
# Elle Brody                         Elizabeth Olsen
# Joe Brody                           Bryan Cranston
# Sandra Brody                      Juliette Binoche
# Houston Brooks                                 NaN
# William Randa                                  NaN
# James Conrad                                   NaN
# Hank Marlow                                    NaN
# ...

# %% [markdown]
# # Saving as CSV File (Step 4)

# %%
df.to_csv('characters.csv', sep = '\t')

# %% [markdown]
# # Bonus Points - Fast & Furious Data

# %% [markdown]
# ## Web Scraping Data

# %%
url = 'https://en.wikipedia.org/wiki/List_of_Fast_%26_Furious_characters'
cars_df = pd.read_html(url)
cars_df = cars_df[2]

# %% [markdown]
# ## Running Function

# %%
clean_table(cars_df)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:3936: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#                        Portrayed by The Fast and the Furious  \
# character
# Dominic Toretto          Vin Diesel                     Main
# Brian O'Conner        Paul Walker †                     Main
# Letty Ortiz      Michelle Rodriguez                     Main
# Mia Toretto        Jordana Brewster                     Main
# Roman Pearce          Tyrese Gibson                      NaN
# ...                             ...                      ...
# Denlinger         Samuel M. Stewart                      NaN
# Mose Jakande         Djimon Hounsou                      NaN
# Kiet                       Tony Jaa                      NaN
# Kara                   Ronda Rousey                      NaN
# ...

# %% [markdown]
# ## Saving CSV File

# %%
cars_df.to_csv('fast&furious.csv')
